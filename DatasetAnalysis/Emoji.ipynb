# %% [markdown]
# # Emoji

# %% [markdown]
# Emoji are pictographs (pictorial symbols) that are typically presented in a colorful form and used inline in text. They represent things such as faces, weather, vehicles and buildings, food and drink, animals and plants, or icons that represent emotions, feelings, or activities. The entire set of official Emoji codes as defined by the unicode consortium (http://www.unicode.org/emoji/charts/full-emoji-list.html) can be accessed after installing the package emoji.

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from pylab import *
import seaborn as sns
import re
import string

# Read csv file
df0 = pd.read_csv('tweets_public2.csv', encoding='utf-16', index_col='tweet_id', sep=',')
# Keep relevant columns only
df = df0.drop(['retweet_count','is_reply','reply_count','tweet_coord','tweet_location','user_timezone'], axis=1)
df.head()
# Out:
#                    airline_sentiment  \
# tweet_id
# 942743012337123328          positive
# 926857871916183553          positive
# 936979305720090626           neutral
# 943983853802328064          negative
# 938207464457211904          negative
#
#                                                                  text  \
# tweet_id
# 942743012337123328  "Los pilotos de Ryanair desconvocan la huelga ...
# 926857871916183553  @Iberia @lavecinarubia Si ,por favor las decla...
# 936979305720090626       @Iberia Me dirías por favor que costo tiene?
# 943983853802328064  @SupermanlopezN @Iberia @giroditalia Champion,...
# 938207464457211904  @SrtaFarrellDM @KLM @Iberia Eso de avianca es ...
#
#                                      tweet_created newairline_sentiment
# tweet_id
# 942743012337123328  Mon Dec 18 13:07:04 +0000 2017             positive
# 926857871916183553  Sat Nov 04 17:05:11 +0000 2017             positive
# 936979305720090626  Sat Dec 02 15:24:09 +0000 2017              neutral
# 943983853802328064  Thu Dec 21 23:17:43 +0000 2017             negative
# 938207464457211904  Wed Dec 06 00:44:25 +0000 2017             negative

# %%
from emoji import UNICODE_EMOJI #pip install emoji
print(UNICODE_EMOJI.values())
# Out:
# dict_values([':1st_place_medal:', ':2nd_place_medal:', ':3rd_place_medal:', ':AB_button_(blood_type):', ':ATM_sign:', ':A_button_(blood_type):', ':Afghanistan:', ':Albania:', ':Algeria:', ':American_Samoa:', ':Andorra:', ':Angola:', ':Anguilla:', ':Antarctica:', ':Antigua_&_Barbuda:', ':Aquarius:', ':Argentina:', ':Aries:', ':Armenia:', ':Aruba:', ':Ascension_Island:', ':Australia:', ':Austria:', ':Azerbaijan:', ':BACK_arrow:', ':B_button_(blood_type):', ':Bahamas:', ':Bahrain:', ':Bangladesh:', ':Barbados:', ':Belarus:', ':Belgium:', ':Belize:', ':Benin:', ':Bermuda:', ':Bhutan:', ':Bolivia:', ':Bosnia_&_Herzegovina:', ':Botswana:', ':Bouvet_Island:', ':Brazil:', ':British_Indian_Ocean_Territory:', ':British_Virgin_Islands:', ':Brunei:', ':Bulgaria:', ':Burkina_Faso:', ':Burundi:', ':CL_button:', ':COOL_button:', ':Cambodia:', ':Cameroon:', ':Canada:', ':Canary_Islands:', ':Cancer:', ':Cape_Verde:', ':Capricorn:', ':Caribbean_Netherlands:', ':Cayman_Islands:', ':Central_African_Republic:', ':Ceuta_&_Melilla:', ':Chad:', ':Chile:', ':China:', ':Christmas_Island:', ':Christmas_tree:', ':Clipperton_Island:', ':Cocos_(Keeling)_Islands:', ':Colombia:', ':Comoros:', ':Congo_-_Brazzaville:', ':Congo_-_Kinshasa:', ':Cook_Islands:', ':Costa_Rica:', ':Croatia:', ':Cuba:', ':Curaçao:', ':Cyprus:', ':Czechia:', ':Côte_d’Ivoire:', ':Denmark:', ':Diego_Garcia:', ':Djibouti:', ':Dominica:', ':Dominican_Republic:', ':END_arrow:', ':Ecuador:', ':Egypt:', ':El_Salvador:', ':England:', ':Equatorial_Guinea:', ':Eritrea:', ':Estonia:', ':Ethiopia:', ':European_Union:', ':FREE_button:', ':Falkland_Islands:', ':Faroe_Islands:', ':Fiji:', ':Finland:', ':France:', ':French_Guiana:', ':French_Polynesia:', ':French_Southern_Territories:', ':Gabon:', ':Gambia:', ':Gemini:', ':Georgia:', ':Germany:', ':Ghana:', ':Gibraltar:', ':Greece:', ':Greenland:', ':Grenada:', ':Guadeloupe:', ':Guam:', ':Guatemala:', ':Guernsey:', ':Guinea:', ':Guinea-Bissau:', ':Guyana:', ':Haiti:', ':Heard_&_McDonald_Islands:', ':Honduras:', ':Hong_Kong_SAR_China:', ':Hungary:', ':ID_button:', ':Iceland:', ':India:', ':Indonesia:', ':Iran:', ':Iraq:', ':Ireland:', ':Isle_of_Man:', ':Israel:', ':Italy:', ':Jamaica:', ':Japan:', ':Japanese_acceptable_button:', ':Japanese_application_button:', ':Japanese_bargain_button:', ':Japanese_castle:', ':Japanese_congratulations_button:', ':Japanese_discount_button:', ':Japanese_dolls:', ':Japanese_free_of_charge_button:', ':Japanese_here_button:', ':Japanese_monthly_amount_button:', ':Japanese_no_vacancy_button:', ':Japanese_not_free_of_charge_button:', ':Japanese_open_for_business_button:', ':Japanese_passing_grade_button:', ':Japanese_post_office:', ':Japanese_prohibited_button:', ':Japanese_reserved_button:', ':Japanese_secret_button:', ':Japanese_service_charge_button:', ':Japanese_symbol_for_beginner:', ':Japanese_vacancy_button:', ':Jersey:', ':Jordan:', ':Kazakhstan:', ':Kenya:', ':Kiribati:', ':Kosovo:', ':Kuwait:', ':Kyrgyzstan:', ':Laos:', ':Latvia:', ':Lebanon:', ':Leo:', ':Lesotho:', ':Liberia:', ':Libra:', ':Libya:', ':Liechtenstein:', ':Lithuania:', ':Luxembourg:', ':Macau_SAR_China:', ':Macedonia:', ':Madagascar:', ':Malawi:', ':Malaysia:', ':Maldives:', ':Mali:', ':Malta:', ':Marshall_Islands:', ':Martinique:', ':Mauritania:', ':Mauritius:', ':Mayotte:', ':Mexico:', ':Micronesia:', ':Moldova:', ':Monaco:', ':Mongolia:', ':Montenegro:', ':Montserrat:', ':Morocco:', ':Mozambique:', ':Mrs._Claus:', ':Mrs._Claus_dark_skin_tone:', ':Mrs._Claus_light_skin_tone:', ':Mrs._Claus_medium-dark_skin_tone:', ':Mrs._Claus_medium-light_skin_tone:', ':Mrs._Claus_medium_skin_tone:', ':Myanmar_(Burma):', ':NEW_button:', ':NG_button:', ':Namibia:', ':Nauru:', ':Nepal:', ':Netherlands:', ':New_Caledonia:', ':New_Zealand:', ':Nicaragua:', ':Niger:', ':Nigeria:', ':Niue:', ':Norfolk_Island:', ':North_Korea:', ':Northern_Mariana_Islands:', ':Norway:', ':OK_button:', ':OK_hand:', ':OK_hand_dark_skin_tone:', ':OK_hand_light_skin_tone:', ':OK_hand_mediu ...

# %% [markdown]
# We select from the dictionary of UNICODE emojis those clearly associated with positive or negative emotions. We took:
# https://unicode.org/emoji/charts/full-emoji-list.html
# as a reference. Those associated with negative emotions have shortnames with words such as *fear*, *worried*, *frown*, *cry*, *scream*, etc. While those associated with positive emotions have shortnames containing words such as *grin*, *joy*, *smile*, *OK*, *thumbs up*, etc
# We identify the list of positive/negative emoji shortnames using regular expressions.

# %%
def get_emoji(patterns,thelist):
    elist = []
    for pattern in patterns:
        for emoji in thelist:
            match = re.search(pattern,emoji)
            if match: elist.append(emoji)
    return elist

# List of UNICODE emojis
unicodeemojilist = list(UNICODE_EMOJI.values())

# Regular expressions to cast negative emojis
negative_patterns = [re.compile(r'.*frown.*(face)'),re.compile(r'confounded'),re.compile(r'disappoint'),
                     re.compile(r'worried'),re.compile(r'crying'),re.compile(r'\bang[er][ry]'),re.compile(r'fear'),
                     re.compile(r'weary'),re.compile(r'exploding_face'),re.compile(r'grimacing'),
                     re.compile(r'face_with_steam_from_nose'),re.compile(r'pouting_face'),re.compile(r'sleepy_face'),
                     re.compile(r'downcast_face_with_sweat'),re.compile(r'unamused_face'),
                     re.compile(r'see-no-evil_monkey'),re.compile(r'pensive_face'),re.compile(r'persevering_face'),
                     re.compile(r'anxi'),re.compile(r'scream'),re.compile(r'hot_face'),re.compile(r'flushed'),
                     re.compile(r'zany_face'),re.compile(r'dizzy.*(face)'),re.compile(r'face_with_symbols_on_mouth'),
                     re.compile(r'thumbs_down:'),re.compile(r'middle_finger:'),re.compile(r'broken_heart')]
# Regular expressions to cast positive emojis
positive_patterns = [re.compile(r'grin'),re.compile(r'joy'),re.compile(r'smil'),re.compile(r'kiss:'),re.compile(r'wink'),
           re.compile(r'savoring_food'),re.compile(r'[^broken|couple_with]\wheart'),re.compile(r'thumbs_up:'),
           re.compile(r'OK_hand:'),re.compile(r'clapping_hands:'),re.compile(r'waving_hand:'),
           re.compile(r'raised_hand:'),re.compile(r':relieved_face')]    
                
# List of negative/positive emojis shortnames
negative_emoji_shortname = get_emoji(negative_patterns,unicodeemojilist)
positive_emoji_shortname = get_emoji(positive_patterns,unicodeemojilist)

print(positive_emoji_shortname)
# Out:
# [':grinning_cat_face:', ':grinning_cat_face_with_smiling_eyes:', ':grinning_face:', ':grinning_face_with_big_eyes:', ':grinning_face_with_smiling_eyes:', ':grinning_face_with_sweat:', ':grinning_squinting_face:', ':cat_face_with_tears_of_joy:', ':face_with_tears_of_joy:', ':joystick:', ':beaming_face_with_smiling_eyes:', ':cat_face_with_wry_smile:', ':grinning_cat_face_with_smiling_eyes:', ':grinning_face_with_smiling_eyes:', ':kissing_face_with_smiling_eyes:', ':slightly_smiling_face:', ':smiling_cat_face_with_heart-eyes:', ':smiling_face:', ':smiling_face_with_halo:', ':smiling_face_with_heart-eyes:', ':smiling_face_with_horns:', ':smiling_face_with_smiling_eyes:', ':smiling_face_with_sunglasses:', ':face_blowing_a_kiss:', ':kiss:', ':winking_face:', ':winking_face_with_tongue:', ':face_savoring_food:', ':beating_heart:', ':growing_heart:', ':heavy_heart_exclamation:', ':red_heart:', ':revolving_hearts:', ':sparkling_heart:', ':thumbs_up:', ':OK_hand:', ':clapping_hands:', ':waving_hand:', ':raised_hand:', ':relieved_face:']

# %% [markdown]
# We extract the unicode emojis from their shortnames.

# %%
def get_emoji(mydict,emojiShortname):
    return list(mydict.keys())[list(mydict.values()).index(emojiShortname)]

# List of negative/positive emojis
nlist = []
for emoji in negative_emoji_shortname:
    nlist.append(get_emoji(UNICODE_EMOJI,emoji)) 
plist = []
for emoji in positive_emoji_shortname:
    plist.append(get_emoji(UNICODE_EMOJI,emoji))

# %%
elist = nlist+plist
print(elist)
# Out:
# ['☹', '😦', '🙁', '😖', '😞', '😟', '😿', '😢', '😭', '💢', '😠', '👿', '😱', '😨', '🙀', '😩', '😬', '😤', '😡', '😪', '😓', '😒', '🙈', '😔', '😣', '😰', '😱', '😳', '\U0001f92a', '😵', '\U0001f92c', '👎', '🖕', '💔', '😺', '😸', '😀', '😃', '😄', '😅', '😆', '😹', '😂', '🕹', '😁', '😼', '😸', '😄', '😙', '🙂', '😻', '☺', '😇', '😍', '😈', '😊', '😎', '😘', '💏', '😉', '😜', '😋', '💓', '💗', '❣', '❤', '💞', '💖', '👍', '👌', '👏', '👋', '✋', '😌']

# %%
def get_emoji(tweet): 
    inemoji = []
    for emoji in elist:
        match = tweet.find(emoji)
        if match != -1: 
            inemoji.append(emoji)
    return inemoji 

df['emojis'] = df['text'].apply(get_emoji)

# %%
def num_emoji(tweet,emojilist):
    inemoji = []
    for emoji in emojilist:
        match = tweet.find(emoji)
        if match != -1: inemoji.append(emoji)
    return len(inemoji) 

df['emopos'] = df['text'].apply(num_emoji,emojilist=plist)
df['emoneg'] = df['text'].apply(num_emoji,emojilist=nlist)
df.head()
# Out:
#                    airline_sentiment  \
# tweet_id
# 942743012337123328          positive
# 926857871916183553          positive
# 936979305720090626           neutral
# 943983853802328064          negative
# 938207464457211904          negative
#
#                                                                  text  \
# tweet_id
# 942743012337123328  "Los pilotos de Ryanair desconvocan la huelga ...
# 926857871916183553  @Iberia @lavecinarubia Si ,por favor las decla...
# 936979305720090626       @Iberia Me dirías por favor que costo tiene?
# 943983853802328064  @SupermanlopezN @Iberia @giroditalia Champion,...
# 938207464457211904  @SrtaFarrellDM @KLM @Iberia Eso de avianca es ...
#
#                                      tweet_created newairline_sentiment  \
# tweet_id
# 942743012337123328  Mon Dec 18 13:07:04 +0000 2017             positive
# 926857871916183553  Sat Nov 04 17:05:11 +0000 2017             positive
# 936979305720090626  Sat Dec 02 15:24:09 +0000 2017              neutral
# 943983853802328064  Thu Dec 21 23:17:43 +0000 2017             negative
# 938207464457211904  Wed Dec 06 00:44:25 +0000 2017             negative
#
#                    emojis  emopos  emoneg
# tweet_id
# 942743012337123328     []       0       0
# 926857871916183553     []       0       0
# 936979305720090626     []       0       0
# 943983853802328064     []       0       0
# 938207464457211904    [😤]       0       1

# %% [markdown]
# Let's check some tweet examples:

# %%
tweet = df.loc[946415752038535168]
print(tweet)
# Out:
# airline_sentiment                                                 neutral
# text                    ¡Fue espectacular! 👍🏼😉 RT @Iberia: Ahora que y...
# tweet_created                              Thu Dec 28 16:21:13 +0000 2017
# newairline_sentiment                                              neutral
# emojis                                                             [😉, 👍]
# emopos                                                                  2
# emoneg                                                                  0
# Name: 946415752038535168, dtype: object

# %%
tweet = df.loc[947128934705123335] #927259106674651136] #
print(tweet)
# Out:
# airline_sentiment                                                negative
# text                    @Iberia felicitando las Pascuas 😠 https://t.co...
# tweet_created                              Sat Dec 30 15:35:09 +0000 2017
# newairline_sentiment                                             negative
# emojis                                                                [😠]
# emopos                                                                  0
# emoneg                                                                  1
# Name: 947128934705123335, dtype: object

# %% [markdown]
# Using emoticons we were able to identify 70 aprox. According to this article (https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4671607/) about 4% of tweets in Twitter contain emojis. 4% of 6813 tweets would be about ~272 for our sample.

# %%
df['emoneg'].sum()+ df['emoneg'].sum()
# Out:
# 280

# %%
# Create a new column with the sum of emopos and emoneg
df['sum_emoji'] = df['emopos'] + df['emoneg']
# Select only tweets with emoji
dfEmoji = df[df.sum_emoji >= 1]

# %%
# Check the dataset of tweet containing emoji
dfEmoji
# Out:
#                    airline_sentiment  \
# tweet_id
# 938207464457211904          negative
# 924989371480240128           neutral
# 941366647897681922          positive
# 930607170277773312          negative
# 935513720587014144          negative
# 941315427547992064          negative
# 937121508744409088          positive
# 927652461246058497           neutral
# 942463033024090112          negative
# 927924836579627009          positive
# 923532679567630336          positive
# 942549858703020032          negative
# 948307108616957952          negative
# 935624076118384640          positive
# 936571920505561088           neutral
# 930645478362009600           neutral
# 945106690239852549          positive
# 946415752038535168           neutral
# 927497607018156032          negative
# 930595880432013312          negative
# 936285177491357697          negative
# 930864318857564164          negative
# 950391790892388352          negative
# 936626846782885895           neutral
# 942095967708426240          positive
# 947427417399922691          negative
# 935196398479396864           neutral
# 931487175367188480           neutral
# 936625590517555200          positive
# 923322710754816000          negative
# ...                              ...
# 943201206884884481           neutral
# 943101757525196800           neutral
# 938430800915288065           neutral
# 943117278102552576           neutral
# 927899525834006535          negative
# 938065619634835456          negative
# 930569926536060930          positive
# 926586564733435905          negative
# 941299496985743360          positive
# 928002432860344320          positive
# 940976621040873473          negative
# 926853310468018176          negative
# 931553899277844480          positive
# 941335452329574400           neutral
# 936906607945859072          negative
# 947497121917390853          negative
# 936117387803484160           neutral
# 933696765630582785           neutral
# 945750203822469121           neutral
# 937301781016694784          positive
# 935453428532367360          positive
# 932876284597764096           neutral
# 941714059505913857          positive
# 926721881859874816          negative
# 946327345727705089          positive
# 933627331872161792           neutral
# 945981912493035520          positive
# 942062237870690304          negative
# 948299602092011520          negative
# 936237786897747968          positive
#
#                                                                  text  \
# tweet_id
# 938207464457211904  @SrtaFarrellDM @KLM @Iberia Eso de avianca es ...
# 924989371480240128   @AlvProdz La A de... 😂😂😂 https://t.co/CmZuDTHQjz
# 941366647897681922  90 años 🎂\nMuchos vuelos 🛫\n¡Muchas felicidade...
# 930607170277773312                         @Iberia @Iberia ya gané? 😓
# 935513720587014144  @rafallopz @Iberia Yo viajo con Iberia en ener...
# 941315427547992064  @Iberia @WavesANDWind Decidme por favor que te...
# 937121508744409088  2 meses y empiezo a trabajar con Iberia, que r...
# 927652461246058497  @Iberia #HolaArgentina ¡Que nerviosssss y que ...
# 942463033024090112  Como no pueda volar esta Navidad, me acordaré ...
# 927924836579627009              @Iberia Hola Colombia! #Holacolombia✋
# 923532679567630336  @SamsungEspana @Iberia Me encanta 😊 muy buena ...
# 942549858703020032  @guudpt Con Ryanair no duermo pero por el mied...
# 948307108616957952  @ILopezMunoz @josue112014 @jmanatol @AlexValer...
# 935624076118384640  Me encanta que lleven a #bloggers a mostrar de...
# 936571920505561088  Miradas... 😍 @Airbus #A346 “Miguel Servet” de ...
# 930645478362009600  @Iberia Perfecto estaré atenta...como saber si...
# 945106690239852549                            @Iberia Igualmente ❤️❤️
# 946415752038535168  ¡Fue espectacular! 👍🏼😉 RT @Iberia: Ahora que y...
# 927497607018156032  @mherrerogmn @YorokobuMag Aaaayyyy 🙈🙈🙈 En los ...
# 930595880432013312  El viaje más largo que he tenido ha sido desde...
# 936285177491357697  @Iberia gracias pero creo que esta vez @Ryanai...
# 930864318857564164  En el aniversario de la pérdida de mi maleta @...
# 950391790892388352  Muchas gracias por las 2h de retraso en Vigo @...
# 936626846782885895  ¿España contra Portugal?😡 Deberían unirse y se...
# 942095967708426240  Si es verdad lo de “aterrizaje duro, aterrizaj...
# 947427417399922691  Hola @Iberia Creéis que llegaremos a cenar con...
# 935196398479396864  Queremos agradecer a #JUST😀Iberia los tratamie...
# 931487175367188480  😢😢😢 no hay nueva camiseta 🐝 https://t.co/Fnt23...
# 936625590517555200  @Iberia Genial!\nPero ya pude finalizar el che...
# 923322710754816000  Oye que el domingo cojo yo un avion😅 guardarme...
# ...                                                               ...
# 943201206884884481  @Iberia @AirNostrumLAM Que buena noticia...oja...
# 943101757525196800  @d3Mada @Ra_Maat Eso también lo dice mi tarjet...
# 938430800915288065          @FlyVLC @Ryanair @valenciaplaza Gracias 😊
# 943117278102552576  Y así fue el primer vuelo de @Iberia hace 90 s...
# 927899525834006535  @Pagando_Canon Si si, ríete, pero no cojas bil...
# 938065619634835456  Pregunta técnica @Iberia, se puede ver RTVE.es...
# 930569926536060930  Creo que después de tanto viajar con vosotros ...
# 926586564733435905  @andrea6ch Jajaj igual que yo, llevo intentand...
# 941299496985743360     @PikerPilot @Iberia Felicidades Aviador!!!😊😙😙😙
# 928002432860344320  Overbooking en el vuelo y se quedan 10 persona...
# 940976621040873473  @luisangelmate @Iberia No fallan! Es #Iberia e...
# 926853310468018176  Y es que no nos sorprende... Os contamos la ca...
# 931553899277844480  @Iberia con tu avión esta mañana te deseo un f...
# 941335452329574400  @rubenmartinweb @Iberia Tweet promocionado????😂😂😂
# 936906607945859072  Como alguien que mide más de 1.70 m puede sent...
# 947497121917390853  @Albercampeontv Que cabron! La del Mallorca de...
# 936117387803484160  Niebla densa y no se puede despegar sin visibi...
# 933696765630582785  @SWEuskadi Yes me muevo por las dos,los de Ibe...
# 945750203822469121  Cuando Ryanair dice: 'vuelo con llegada a Vale...
# 937301781016694784  Ya en España!!! Pero he perdido el avión a Mal...
# 935453428532367360  @viajarlocura @flywithlevelES @bcnTB @DePronto...
# 932876284597764096  @lussac @Azul_De_Luna Iberia! Estos coruños no...
# 941714059505913857  Estoy en el estreno de Star Wars en la sala VI...
# 926721881859874816  Ryanair cancela los vuelos de Lanzarote con Ba...
# 946327345727705089  Es 28D, pero no es broma si digo que en @Iberi...
# 933627331872161792  @jupa_torres @VivaAerobus @Ryanair No se nos o...
# 945981912493035520  @CarlsJrES @EuniceMKT @CocaCola_es @Iberia @Mk...
# 942062237870690304  Debe ser el único empleado de Ryanair que no o...
# 948299602092011520  @ILopezMunoz @josue112014 @jmanatol @AlexValer...
# 936237786897747968                           @Ryanair Fuerteventura 😎
#
#                                      tweet_created newairline_sentiment  \
# tweet_id
# 938207464457211904  Wed Dec 06 00:44:25 +0000 2017             negative
# 924989371480240128  Mon Oct 30 13:20:26 +0000 2017              neutral
# 941366647897681922  Thu Dec 14 17:57:53 +0000 2017             positive
# 930607170277773312  Wed Nov 15 01:23:33 +0000 2017             negative
# 935513720587014144  Tue Nov 28 14:20:26 +0000 2017             negative
# 941315427547992064  Thu Dec 14 14:34:21 +0000 2017             negative
# 937121508744409088  Sun Dec 03 00:49:13 +0000 2017             positive
# 927652461246058497  Mon Nov 06 21:42:36 +0000 2017              neutral
# 942463033024090112  Sun Dec 17 18:34:31 +0000 2017             negative
# 927924836579627009  Tue Nov 07 15:44:55 +0000 2017             positive
# 923532679567630336  Thu Oct 26 12:52:03 +0000 2017             positive
# 942549858703020032  Mon Dec 18 00:19:32 +0000 2017             negative
# 948307108616957952  Tue Jan 02 21:36:48 +0000 2018             negative
# 935624076118384640  Tue Nov 28 21:38:57 +0000 2017             positive
# 936571920505561088  Fri Dec 01 12:25:21 +0000 2017              neutral
# 930645478362009600  Wed Nov 15 03:55:47 +0000 2017              neutral
# 945106690239852549  Mon Dec 25 01:39:28 +0000 2017             positive
# 946415752038535168  Thu Dec 28 16:21:13 +0000 2017              neutral
# 927497607018156032  Mon Nov 06 11:27:16 +0000 2017             negative
# 930595880432013312  Wed Nov 15 00:38:42 +0000 2017             negative
# 936285177491357697  Thu Nov 30 17:25:56 +0000 2017             negative
# 930864318857564164  Wed Nov 15 18:25:22 +0000 2017             negative
# 950391790892388352  Mon Jan 08 15:40:35 +0000 2018             negative
# 936626846782885895  Fri Dec 01 16:03:36 +0000 2017              neutral
# 942095967708426240  Sat Dec 16 18:15:56 +0000 2017             positive
# 947427417399922691  Sun Dec 31 11:21:13 +0000 2017             negative
# 935196398479396864  Mon Nov 27 17:19:31 +0000 2017              neutral
# 931487175367188480  Fri Nov 17 11:40:23 +0000 2017              neutral
# 936625590517555200  Fri Dec 01 15:58:37 +0000 2017             positive
# 923322710754816000  Wed Oct 25 22:57:43 +0000 2017             negative
# ...                                            ...                  ...
# 943201206884884481  Tue Dec 19 19:27:46 +0000 2017              neutral
# 943101757525196800  Tue Dec 19 12:52:35 +0000 2017              neutral
# 938430800915288065  Wed Dec 06 15:31:52 +0000 2017              neutral
# 943117278102552576  Tue Dec 19 13:54:16 +0000 2017              neutral
# 927899525834006535  Tue Nov 07 14:04:21 +0000 2017             negative
# 938065619634835456  Tue Dec 05 15:20:46 +0000 2017             negative
# 930569926536060930  Tue Nov 14 22:55:34 +0000 2017             positive
# 926586564733435905  Fri Nov 03 23:07:06 +0000 2017             negative
# 941299496985743360  Thu Dec 14 13:31:03 +0000 2017             positive
# 928002432860344320  Tue Nov 07 20:53:16 +0000 2017             positive
# 940976621040873473  Wed Dec 13 16:08:03 +0000 2017             negative
# 926853310468018176  Sat Nov 04 16:47:03 +0000 2017             negative
# 931553899277844480  Fri Nov 17 16:05:31 +0000 2017             positive
# 941335452329574400  Thu Dec 14 15:53:55 +0000 2017              neutral
# 936906607945859072  Sat Dec 02 10:35:16 +0000 2017             negative
# 947497121917390853  Sun Dec 31 15:58:12 +0000 2017             negative
# 936117387803484160  Thu Nov 30 06:19:12 +0000 2017              neutral
# 933696765630582785  Thu Nov 23 14:00:30 +0000 2017              neutral
# 945750203822469121  Tue Dec 26 20:16:34 +0000 2017              neutral
# 937301781016694784  Sun Dec 03 12:45:33 +0000 2017             positive
# 935453428532367360  Tue Nov 28 10:20:51 +0000 2017             positive
# 932876284597764096  Tue Nov 21 07:40:12 +0000 2017              neutral
# 941714059505913857  Fri Dec 15 16:58:22 +0000 2017             positive
# 926721881859874816  Sat Nov 04 08:04:48 +0000 2017             negative
# 946327345727705089  Thu Dec 28 10:29:55 +0000 2017             positive
# 933627331872161792  Thu Nov 23 09:24:36 +0000 2017              neutral
# 945981912493035520  Wed Dec 27 11:37:18 +0000 2017             positive
# 942062237870690304  Sat Dec 16 16:01:54 +0000 2017             negative
# 948299602092011520  Tue Jan 02 21:06:58 +0000 2018             negative
# 936237786897747968  Thu Nov 30 14:17:37 +0000 2017             positive
#
#                        emojis  emopos  emoneg  sum_emoji
# tweet_id
# 938207464457211904        [😤]       0       1          1
# 924989371480240128        [😂]       1       0          1
# 941366647897681922        [😉]       1       0          1
# 930607170277773312        [😓]       0       1          1
# 935513720587014144     [😨, 😓]       0       2          2
# 941315427547992064        [😞]       0       1          1
# 937121508744409088        [❤]       1       0          1
# 927652461246058497     [😍, ❤]       2       0          2
# 942463033024090112        [😒]       0       1          1
# 927924836579627009        [✋]       1       0          1
# 923532679567630336        [😊]       1       0          1
# 942549858703020032        [😭]       0       1          1
# 948307108616957952        [😂]       1       0          1
# 935624076118384640     [👌, 👏]       2       0          2
# 936571920505561088        [😍]       1       0          1
# 930645478362009600        [😂]       1       0          1
# 945106690239852549        [❤]       1       0          1
# 946415752038535168     [😉, 👍]       2       0          2
# 927497607018156032        [🙈]       0       1          1
# 930595880432013312     [💔, 😂]       1       1          2
# 936285177491357697        [😔]       0       1          1
# 930864318857564164        [😊]       1       0          1
# 950391790892388352        [👌]       1       0          1
# 936626846782885895        [😡]       0       1          1
# 942095967708426240        [😅]       1       0          1
# 947427417399922691        [😡]       0       1          1
# 935196398479396864        [😀]       1       0          1
# 931487175367188480        [😢]       0       1          1
# 936625590517555200     [😄, 😄]       2       0          2
# 923322710754816000  [😅, 😂, 😇]       3       0          3
# ...                       ...     ...     ...        ...
# 943201206884884481        [👍]       1       0          1
# 943101757525196800        [😂]       1       0          1
# 938430800915288065        [😊]       1       0          1
# 943117278102552576        [😍]       1       0          1
# 927899525834006535        [😂]       1       0          1
# 938065619634835456        [😊]       1       0          1
# 930569926536060930        [🙈]       0       1          1
# 926586564733435905        [🙈]       0       1          1
# 941299496985743360     [😙, 😊]       2       0          2
# 928002432860344320        [👏]       1       0          1
# 940976621040873473     [👎, 😂]       1       1          2
# 926853310468018176        [👎]       0       1          1
# 931553899277844480        [👋]       1       0          1
# 941335452329574400        [😂]       1       0          1
# 936906607945859072        [😤]       0       1          1
# 947497121917390853        [😍]       1       0          1
# 936117387803484160        [😅]       1       0          1
# 933696765630582785        [😂]       1       0          1
# 945750203822469121        [😂]       1       0          1
# 937301781016694784        [😀]       1       0          1
# 935453428532367360        [😂]       1       0          1
# 932876284597764096        [😂]       1       0          1
# 941714059505913857        [😊]       1       0          1
# 926721881859874816        [😔]       0       1          1
# 946327345727705089        [😍]       1       0          1
# 933627331872161792  [😱, 😱, 😍]       1       2          3
# 945981912493035520        [😊]       1       0          1
# 942062237870690304        [❤]       1       0          1
# 948299602092011520        [😜]       1       0          1
# 936237786897747968        [😎]       1       0          1
#
# [378 rows x 8 columns]

# %%
# Dataset of tweets containing only positive emoji
dfOnlyPositive = dfEmoji[dfEmoji['emoneg'] == 0]

print('Number of tweets with only positive emoji:',dfOnlyPositive['emopos'].count())
counts = dfOnlyPositive['newairline_sentiment'].value_counts()/(dfOnlyPositive['emopos'].count())
print(counts)
# Out:
# Number of tweets with only positive emoji: 254
# positive    0.421260
# neutral     0.385827
# negative    0.192913
# Name: newairline_sentiment, dtype: float64

# %%
# Plot
rcParams['font.size'] = 16.0
matplotlib.rcParams['lines.linewidth'] = 7
# Say, "the default sans-serif font is COMIC SANS"
matplotlib.rcParams['font.sans-serif'] = "League Gothic"
# Then, "ALWAYS use sans-serif fonts"
matplotlib.rcParams['font.family'] = "sans-serif"

plt.title('Airline Sentiment for Tweets with only Positive Emoji')
plt.pie(counts,labels=['Positive','Neutral','Negative'],
       colors=[sns.xkcd_rgb["medium green"],sns.xkcd_rgb["steel blue"],sns.xkcd_rgb["pale red"]],
       labeldistance=1.1,startangle=120,
        shadow=False,autopct='%.2f%%',
        wedgeprops={"edgecolor":"k",'linewidth': 0.5, 'linestyle': 'solid', 'antialiased': True})
fig = plt.gcf()
fig.set_size_inches(6,6)
fig.savefig('piechartEMOPOS.jpg', bbox_inches='tight',dpi=300)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Tweets with positive emojis with negative sentiment labels??? Let's check the list of tweets in this category... By inspecting the text we find sarcasm and some mislabeling.

# %%
dfOnlyPositive[dfOnlyPositive['newairline_sentiment'] == 'negative'].text.tolist()
# Out:
# ['@ILopezMunoz @josue112014 @jmanatol @AlexValeroLEVC @airspottersORG @Ryanair No es por vacilar pero tiene toda la pinta de ser un vueling 😂',
#  'En el aniversario de la pérdida de mi maleta @Iberia ¿Me váis a hacer un regalo? 😊 Solo falta 1 mes!! Qué emoción!',
#  'Muchas gracias por las 2h de retraso en Vigo @Ryanair 👌',
#  'Oye que el domingo cojo yo un avion😅 guardarme alguno no???😂😇 https://t.co/i4R6LoAZ46',
#  '😂😂😂 qué paveros los de @Ryanair! #siempreMejorando dicen, mientras siguen en su escalada de monopolizar y restar se… https://t.co/5mp7s5709I',
#  '@Jonas_bornes00 @Javierromero_00 @Iberia @Ryanair Creo q igual ryanair por ahorrarse dinero en un piloto te dejaría pilotar 😂😂',
#  '@jordibatlle @Iberia Después 1h30’ no está mal ¿No? Me consolaré pensando en que al menos han acabado saliendo 😉',
#  "El segundo flaquito que dice 'hola' de la publicidad de Iberia, está que se parte. Sorry, lo tenia q decir. 😇",
#  'Unos cuantos meses y empiezo a facturar con Iberia❤💸🛫',
#  '@AnaAngiolina @ostinus77 El sitio mas incómodo de todo Barajas junto a la nueva política de embarque de Ryanair. Aquí el resultado😂😂😂',
#  '¿Sabrá lo que es que no le quepan las piernas en #Ryanair? 😂😂 https://t.co/ZbAqysH1UD https://t.co/C1Jt4m0eU0',
#  '@Fotomaf @angeljimenez Los de Iberia diciéndole a Leigh "Ese bulto tan grande no puede ir en cabina" 😈',
#  '@Iberia Sin ninguna duda 😉',
#  'Iberia hoy hace su agosto conmigo 😂😂😂',
#  'Y ahora en el vuelo BIO-MAD de @iberia las instrucciones de seguridad a un volumen que parece el de alguien confesándose en misa 😂',
#  '@adrianadomri @Iberia Espero que no haya sido un viaje muy largo 😅',
#  '@ModoCharlie Ahorita andan compitiendo con RyanAir 😆',
#  '@karlaiberia @bonassomiguel Un invitado de lujo!Excelente entrevista con gran señor.Saludos  desde Saltillo Karla Iberia😊',
#  '@cris_92 E si son caras o fitur podemos ir igual 😂😂😂😂😂 con suerte o ryanair ou o alsa stan baratos xD',
#  '2 horas de retraso (de momento) metidos en él avión, bravo @Iberia 👏🏻',
#  'Wuajajajjaja  en venganza po wn 😂😂😂😂 https://t.co/gKxdQmGcZx',
#  '@FranciscoFdez @Iberia Ánimo, -Fran- 😅😌',
#  '@DomoElectra @Iberia @LaMananaTVE Lo traicionó el  corrector jajajaja o estaba escribiendo en el baño. 😆',
#  'Gracias @Iberia  por retrasar mi vuelo dos horas y hacer que llegue más tarde a casa por Navidad 👏👏',
#  'Gracias a Ryanair por hacer que este día sea aún más largo 👍',
#  'Que te llegue este mail cuando estás embarcando en un vuelo de @Iberia.... ¿se invitarán a algo? 😉 https://t.co/JbeM9TEZB4',
#  '#Miami 😍 desde el #cielo 🛫 con #iberia #USA #light #night #LoveAviation #fly #plane #sky #CuandoVesEnVezDeMirar… https://t.co/MliiVwadkX',
#  '@Ryanair MADRID! 😁💃 #travelthursday',
#  '@_CrisJimenez_ @Iberia Lo siento guapísima ! Espero se solucione 😘',
#  '@JhonatanRVal @Avianca @Iberia Aiiii @JhonatanRVal , parece mentira que viajas todo el tiempo 😂😂😂😂😂 . Son magos par… https://t.co/4uBOd9kbGl',
#  'Ryanair obligará a los andaluces a facturar el duende https://t.co/PyOFCzeV5F vía @elmundotoday 😂😂😂😂',
#  '@AParayas @Ryanair @cant_infinita Si queréis os ayudo con el idioma 😀😀 a cambio de billetes de avión',
#  'Para la proxima no olviden mencionar donde guardan la comida de los NO preferente 😉 https://t.co/mIFvbhxnRw',
#  '@Meridachechu Jajajajajaja así me duermo hasta yo, el billete costará tb 20€ como los míos de Ryanair 😅',
#  '@ibeca73 @Iberia Cuando las encontré en los álbumnes de mis padres no me lo pude creer😲 \nMe encantan😍😍😍',
#  '@vueling @Berlustinho @Gazofilaci Aneu a CAGAR A LA VIA DEL TREN ...\nLo habéis entendido ?\nRYANAIR Mola ...\n😂🤣😁',
#  'Viajar con Ryanair tiene esas cosas 😂😂\nHasta los huevos de esperar https://t.co/9jwnwSHxGg',
#  'Los propósitos de Iberia son los mejores 😍 https://t.co/KyIOaJHIko',
#  '@Ryanair_ES Muy buena publicidad 👏🏻👏🏻👏🏻Desde el aeropuerto de santander esperando a embarcar rumbo a marrakech y si… https://t.co/iW84MJMDjQ',
#  '@PaquiVicente Iberia no me lleva tan rápido 😂😂',
#  'Cuando te cansas de esperar dentro del avión y sales a que te de el aire 😂😂😂 Qué crack ! \n#vuelo #Ryanair #Londres… https://t.co/wjIalyF7FF',
#  '@Ryanair Alicante🙋🏼💓#TravelTuesday',
#  'Felicidades @vueling habeis superado a @Ryanair  en penosidad de servicio! 👏👏 ¿Os habeis tenido que esforzar mucho?',
#  '👋🏽 @Iberia 1vuelo cancelado sin previo aviso, mas de 4H de espera, 1 reclamacion, 5semanas esperando respuesta y to… https://t.co/OxN2Ai8wGP',
#  '@Pagando_Canon Si si, ríete, pero no cojas billete en Ryanair😂',
#  'Pregunta técnica @Iberia, se puede ver RTVE.es en sus vuelos? Un saludo! Gracias 😊',
#  '@Albercampeontv Que cabron! La del Mallorca de Spanair...😍😍',
#  'Debe ser el único empleado de Ryanair que no odia la vida ❤️',
#  '@ILopezMunoz @josue112014 @jmanatol @AlexValeroLEVC @airspottersORG @Ryanair Segundo avión localizado 😜😜😜']

# %%
# Dataset of tweets containing only negative emoji
dfOnlyNegative = dfEmoji[dfEmoji['emopos'] == 0]
print('Number of tweets with only negative emoji:',dfOnlyNegative['emoneg'].count())
counts = dfOnlyNegative['newairline_sentiment'].value_counts()/(dfOnlyNegative['emoneg'].count())
print(counts)

#Plot
plt.title('Airline Sentiment for Tweets with only Negative Emoji')
plt.pie(counts,labels=['Negative','Neutral','Positive'],
        colors=[sns.xkcd_rgb["pale red"],sns.xkcd_rgb["steel blue"],sns.xkcd_rgb["medium green"]],
        labeldistance=1.1,startangle=0,
        shadow=False,autopct='%.2f%%',
        wedgeprops={"edgecolor":"k",'linewidth': 0.5, 'linestyle': 'solid', 'antialiased': True}) 
fig = plt.gcf()
fig.set_size_inches(6,6)
fig.savefig('piechartEMONEG.jpg', bbox_inches='tight',dpi=300)
# Out:
# Number of tweets with only negative emoji: 118
# negative    0.762712
# neutral     0.161017
# positive    0.076271
# Name: newairline_sentiment, dtype: float64
# /anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
dfOnlyNegative[dfOnlyNegative['newairline_sentiment'] == 'positive'].text.tolist()
# Out:
# ['Vuelos de Ryanair a 5€ y... 🙈🙈🙈',
#  'Este domingo volví de Madrid a Málaga en uno de los nuevos aviones de @Iberia y de vuelo no fue más de media hora 😬#quégenial',
#  'Veo los carteles de iberia y me dan ganas de viajar de nuevo 💔',
#  'Me quiero ir a Amsterdam con las ofertas de ryanair😭😭😭',
#  'Con mucho hype de ir a Copenhague 🤔 \nRyanair y sus ofertazas me vuelven loca y pobre 😱😱',
#  '@Ryanair_ES @Ryanair Me encanta viajar y a mi pareja también... y aún no tengo regalo de reyes...y me sacarías del apuro #Ryanair 😓',
#  '@AdQqV @Ryanair Dios! Que precios mas alucinantes! 😱',
#  'Me gustaría hacer prácticas en Iberia pero no tengo tiempo 😭😭',
#  'Creo que después de tanto viajar con vosotros me estoy ganando el carné VIP a pulso @Ryanair 🙈✈️🙄']

# %%
# Dataset of tweets containing both positive and negative emoji
dfBoth = dfEmoji[(dfEmoji['emopos'] >= 1) & (dfEmoji['emoneg'] >= 1)]
dfBoth
# Out:
#                    airline_sentiment  \
# tweet_id
# 930595880432013312          negative
# 938064372898856962          negative
# 938124560855175170          negative
# 930123340987158529          negative
# 940976621040873473          negative
# 933627331872161792           neutral
#
#                                                                  text  \
# tweet_id
# 930595880432013312  El viaje más largo que he tenido ha sido desde...
# 938064372898856962  Llevo una hora esperando al teléfono. \n@Iberi...
# 938124560855175170  @aaruiz07 Que Iberia había aumentado sus vuelo...
# 930123340987158529  @SokingRcQ Pero como vas con Iberia mi niñoooo...
# 940976621040873473  @luisangelmate @Iberia No fallan! Es #Iberia e...
# 933627331872161792  @jupa_torres @VivaAerobus @Ryanair No se nos o...
#
#                                      tweet_created newairline_sentiment  \
# tweet_id
# 930595880432013312  Wed Nov 15 00:38:42 +0000 2017             negative
# 938064372898856962  Tue Dec 05 15:15:49 +0000 2017             negative
# 938124560855175170  Tue Dec 05 19:14:59 +0000 2017             negative
# 930123340987158529  Mon Nov 13 17:21:00 +0000 2017             negative
# 940976621040873473  Wed Dec 13 16:08:03 +0000 2017             negative
# 933627331872161792  Thu Nov 23 09:24:36 +0000 2017              neutral
#
#                        emojis  emopos  emoneg  sum_emoji
# tweet_id
# 930595880432013312     [💔, 😂]       1       1          2
# 938064372898856962  [😱, 😱, 👋]       1       2          3
# 938124560855175170     [🙈, 😂]       1       1          2
# 930123340987158529     [😒, 😂]       1       1          2
# 940976621040873473     [👎, 😂]       1       1          2
# 933627331872161792  [😱, 😱, 😍]       1       2          3

# %%
print('Number of tweets with BOTH positive and negative emoji:',dfBoth['emoneg'].count())
counts = dfBoth['newairline_sentiment'].value_counts()/(dfBoth['emoneg'].count())
print(counts)

# Plot
plt.title('Airline Sentiment for Tweets with BOTH Positive and Negative Emoji')
plt.pie(counts,labels=['Negative','Neutral'],
        colors=[sns.xkcd_rgb["pale red"],sns.xkcd_rgb["steel blue"]],
        labeldistance=1.1,startangle=0,
        shadow=False,autopct='%.2f%%',
        wedgeprops={"edgecolor":"k",'linewidth': 0.5, 'linestyle': 'solid', 'antialiased': True})
fig = plt.gcf()
fig.set_size_inches(6,6)
fig.savefig('piechartEMOPOSEMOPOS.jpg', bbox_inches='tight',dpi=300)
# Out:
# Number of tweets with BOTH positive and negative emoji: 6
# negative    0.833333
# neutral     0.166667
# Name: newairline_sentiment, dtype: float64
# /anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Thus, if a tweet contains a negative emoji and a positive emoji it is probably a negative tweet!!

# %%
dfNoEmoji = df[df.sum_emoji == 0]

# %%
#Print tweets with no emoji
#dfNoEmoji.text.tolist()
