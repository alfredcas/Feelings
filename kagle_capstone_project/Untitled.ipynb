# %%
import pandas as pd

# %%
df = pd.read_csv('tweets_public.csv')

# %%
df['tweet_coord'].dropna()
# Out:
# 29      [39.85871934, -104.67371484]
# 34       [41.97745295, -87.91025951]
# 46        [41.9763291, -87.73856403]
# 56          [1.3523078, 103.8637764]
# 93       [40.64935461, -73.79198785]
# 114     [34.09822952, -118.34307851]
# 176      [33.64314381, -84.44252134]
# 182                       [0.0, 0.0]
# 194       [42.19881665, -83.3859395]
# 207       [29.9880285, -90.25781369]
# 217     [40.03395098, -105.24950187]
# 218      [42.36184505, -71.02219492]
# 246      [45.58931882, -122.5959928]
# 253      [40.69814396, -74.17906717]
# 272     [45.67920767, -111.04847652]
# 288      [40.64679403, -73.77516598]
# 296      [41.06865736, -73.70398273]
# 309      [38.90385896, -76.51625101]
# 340      [33.18882771, -96.64036423]
# 359        [42.3427148, -71.5504243]
# 389      [30.44414315, -84.23627649]
# 407       [41.86591706, -87.6231238]
# 410      [30.26196639, -97.75945775]
# 436     [33.75357228, -116.36206155]
# 466      [35.22363719, -80.94045544]
# ...

# %%
dfClean = df[].dropna()
